# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os
import struct
import numpy as np

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

# %%
def load_mnist(path, kind='train'):
    """Load MNIST data from `path`"""
    labels_path = os.path.join(path,
                               '%s-labels-idx1-ubyte'
                               % kind)
    images_path = os.path.join(path,
                               '%s-images-idx3-ubyte'
                               % kind)
    with open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack('>II',
                                 lbpath.read(8))
        labels = np.fromfile(lbpath,
                             dtype=np.uint8)

    with open(images_path, 'rb') as imgpath:
        magic, num, rows, cols = struct.unpack('>IIII',
                                               imgpath.read(16))
        images = np.fromfile(imgpath,
                             dtype=np.uint8).reshape((len(labels),28,28))

    return images, labels

# %%
X_train, y_train = load_mnist('./data')
                              
X_test, y_test = load_mnist('./data',kind='t10k')
print(X_test.shape,y_test.shape)
# Out:
# (10000, 28, 28) (10000,)

# %%
def img_show(img):
    plt.figure(figsize=(1,1))
    plt.imshow(img,cmap='Greys',interpolation='nearest')

# %%
def imgs_show(imgs,row,col):
    fig,ax = plt.subplots(nrows=row,ncols=col,sharex=True,sharey=True)
    ax = ax.flatten()
    for i in range(row*col):
        img = imgs[i]
        ax[i].imshow(img,cmap='Greys', interpolation='nearest')
    
    ax[0].set_xticks([])
    ax[0].set_yticks([])
    plt.tight_layout()
    plt.show()

# %%
train_0 = X_train[y_train == 0]
print("train_0.shape = ",train_0.shape)

train_1 = X_train[y_train == 1]
print("train_1.shape = ",train_1.shape)

train_2 = X_train[y_train == 2]
print("train_2.shape = ",train_2.shape)

train_3 = X_train[y_train == 3]
print("train_3.shape = ",train_3.shape)

train_4 = X_train[y_train == 4]
print("train_0.shape = ",train_4.shape)


train_5 = X_train[y_train == 5]
print("train_0.shape = ",train_5.shape)


train_6 = X_train[y_train == 6]
print("train_6.shape = ",train_6.shape)

train_7 = X_train[y_train == 7]
print("train_7.shape = ",train_7.shape)


train_8 = X_train[y_train == 8]
print("train_8.shape = ",train_8.shape)


train_9 = X_train[y_train == 9]
print("train_9.shape = ",train_9.shape)
# Out:
# train_0.shape =  (5923, 28, 28)
# train_1.shape =  (6742, 28, 28)
# train_2.shape =  (5958, 28, 28)
# train_3.shape =  (6131, 28, 28)
# train_0.shape =  (5842, 28, 28)
# train_0.shape =  (5421, 28, 28)
# train_6.shape =  (5918, 28, 28)
# train_7.shape =  (6265, 28, 28)
# train_8.shape =  (5851, 28, 28)
# train_9.shape =  (5949, 28, 28)

# %%
#shuf data
shuf_index = np.random.permutation(len(X_train))
train_x = X_train[shuf_index]
train_y = y_train[shuf_index]
print(y_train[:100])
print(train_y[:100])
# Out:
# [5 0 4 1 9 2 1 3 1 4 3 5 3 6 1 7 2 8 6 9 4 0 9 1 1 2 4 3 2 7 3 8 6 9 0 5 6
#  0 7 6 1 8 7 9 3 9 8 5 9 3 3 0 7 4 9 8 0 9 4 1 4 4 6 0 4 5 6 1 0 0 1 7 1 6
#  3 0 2 1 1 7 9 0 2 6 7 8 3 9 0 4 6 7 4 6 8 0 7 8 3 1]
# [2 6 6 8 2 4 6 1 7 5 6 3 4 2 8 6 1 1 2 7 8 2 0 9 9 6 8 4 6 9 8 1 6 6 2 4 5
#  5 3 6 1 5 1 3 8 0 6 4 8 7 7 7 0 1 9 9 2 5 9 6 3 1 2 7 2 6 1 0 8 2 8 9 5 1
#  4 1 5 7 2 0 3 2 7 9 5 7 5 3 1 8 2 2 3 2 4 2 2 8 5 4]

# %%
def normal_minist(img):
    return (img / 255) -0.5

# %%
def expend_HWC(img):
    return np.expand_dims(img,axis=3)

# %%
def to_CHW(img):
    return np.transpose(img,(0,3,1,2))
def to_HWC(img):
    return np.transpose(img,(0,2,3,1))

# %%
train_real = expend_HWC(train_x)
train_real = normal_minist(train_real)
print(train_real.shape)
train_real = to_CHW(train_real)
print(train_real.shape)


test_real = expend_HWC(X_test)
test_real = normal_minist(test_real)
print(test_real.shape)
test_real = to_CHW(test_real)
print(test_real.shape)
# Out:
# (60000, 28, 28, 1)
# (60000, 1, 28, 28)
# (10000, 28, 28, 1)
# (10000, 1, 28, 28)

# %%
print(train_real[0])
imgs_show(np.squeeze (train_real[50000:50025]),5,5)
print(train_y[50000:50100])
# Out:
# [[[-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.20196078  0.41764706  0.49607843  0.13921569 -0.06078431
#    -0.45686275 -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#     0.02941176  0.48039216  0.49215686  0.49215686  0.35490196  0.47647059
#     0.07647059 -0.3745098  -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.0254902   0.43333333  0.49215686  0.48039216  0.34705882 -0.44901961
#    -0.29215686  0.42156863  0.39411765 -0.39803922 -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#     0.21372549  0.49215686  0.49215686  0.24117647 -0.5        -0.5        -0.5
#    -0.20588235  0.47647059 -0.24901961 -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.08823529  0.46862745  0.13529412 -0.4372549  -0.5        -0.5        -0.5
#    -0.35490196  0.49215686  0.00588235 -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.42156863  0.03333333  0.18235294 -0.14313725
#    -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.4372549
#    -0.11176471  0.49607843  0.49607843 -0.28823529 -0.21372549 -0.03333333
#     0.1627451   0.49607843  0.5         0.49607843  0.49607843  0.49607843
#     0.39411765 -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.4372549  -0.19411765
#     0.44117647  0.49215686  0.49215686  0.44509804  0.49215686  0.49215686
#     0.49215686  0.49215686  0.49607843  0.49215686  0.38235294  0.25294118
#    -0.1        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.4254902   0.15098039  0.35098039  0.39411765  0.49215686
#     0.49215686  0.49215686  0.49215686  0.49607843  0.49215686  0.41764706
#     0.09215686  0.09215686 -0.22941176 -0.35882353 -0.42941176 -0.5        -0.5
#    -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.2372549   0.44901961  0.49215686  0.49607843  0.49215686
#     0.49215686  0.46078431  0.06470588 -0.15882353 -0.28823529 -0.39411765
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.35098039  0.13529412  0.13921569  0.13529412
#    -0.16666667 -0.2372549  -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]
#   [-0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5
#    -0.5        -0.5        -0.5        -0.5        -0.5        -0.5        -0.5       ]]]
# [3 9 9 4 5 7 1 3 5 9 7 6 1 1 9 3 5 4 1 0 4 5 6 7 7 1 1 2 3 9 4 9 7 4 6 6 6
#  1 0 7 9 7 7 9 1 4 1 6 7 5 1 0 7 3 8 8 6 2 6 9 8 5 8 5 8 6 1 3 1 8 4 8 0 1
#  1 2 6 2 6 4 7 8 0 5 4 2 8 2 3 2 7 5 1 7 6 7 4 7 6 0]

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)
        self.features={}

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        self.features['relu1'] = x
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def getnext(train_x,train_y,batch_size):
    batchs = len(train_y) // batch_size
    print(len(train_y),batchs)

    for i in range(batchs):
        x = train_x[batch_size * i : batch_size * (i+1)]
        y = train_y[batch_size * i : batch_size * (i+1)]
        yield x,y

# %%
datas = getnext(train_real,train_y,20000)

for x,y in datas:
    print(x.shape)
    print(y.shape)
# Out:
# 60000 3
# (20000, 1, 28, 28)
# (20000,)
# (20000, 1, 28, 28)
# (20000,)
# (20000, 1, 28, 28)
# (20000,)

# %%
use_cuda = torch.cuda.is_available()
torch.manual_seed(666)
device = torch.device("cuda" if use_cuda else "cpu")
net = Net().to(device)
net.double()

optimizer = optim.SGD(net.parameters(),lr=0.003,momentum=0.9)

# %%
net.train()
for epoch in range(20):
    datas = getnext(train_real,train_y,64)
    for x,y in datas:
        inputs, labels = Variable(torch.from_numpy(x)).to(device), Variable(torch.from_numpy(y).long()).to(device)
#         print(labels)
        optimizer.zero_grad()
        output = net(inputs)
#         print(output.size())
        loss = F.nll_loss(output,labels)
        loss.backward()
        optimizer.step()
        
    print('%d  loss: %.3f' % (epoch ,  loss.item()))
torch.save(net,'model.pkl')
# Out:
# 60000 937
# 0  loss: 0.685
# 60000 937
# 1  loss: 0.618
# 60000 937
# 2  loss: 0.436
# 60000 937
# 3  loss: 0.293
# 60000 937
# 4  loss: 0.225
# 60000 937
# 5  loss: 0.185
# 60000 937
# 6  loss: 0.257
# 60000 937
# 7  loss: 0.160
# 60000 937
# 8  loss: 0.190
# 60000 937
# 9  loss: 0.215
# 60000 937
# 10  loss: 0.149
# 60000 937
# 11  loss: 0.066
# 60000 937
# 12  loss: 0.192
# 60000 937
# 13  loss: 0.137
# 60000 937
# 14  loss: 0.241
# 60000 937
# 15  loss: 0.152
# 60000 937
# 16  loss: 0.139
# 60000 937
# 17  loss: 0.148
# 60000 937
# 18  loss: 0.049
# 60000 937
# 19  loss: 0.190
# /home/huyu/miniconda3/envs/pytorch/lib/python3.5/site-packages/torch/serialization.py:193: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
net = torch.load('model.pkl')
net.to(device)
net.eval()
test_loss = 0
correct = 0

with torch.no_grad():
    test_datas = getnext(test_real,y_test,32)
    for x ,y in test_datas:
        inputs, labels = Variable(torch.from_numpy(x)).to(device), Variable(torch.from_numpy(y).long()).to(device)
        output = net(inputs)
        test_loss += F.nll_loss(output, labels, size_average=False).item() # sum up batch loss
        pred = output.max(1,keepdim=True)[1]
#         print(pred)
        correct += pred.eq(labels.view_as(pred)).sum().item()
#         print(correct)
        
test_loss /= 10000
print('\nTest set: Average loss: {:.4f}, Accuracy: {} ({:.0f}%)\n'.format(
        test_loss, correct,100. * correct / 10000))
# Out:
# 10000 312
#
# Test set: Average loss: 0.0415, Accuracy: 9854 (99%)

# %%
net.eval()
with torch.no_grad():
    x ,y = train_real[55:56],train_y[55:56]
    inputs, labels = Variable(torch.from_numpy(x)).to(device), Variable(torch.from_numpy(y).long()).to(device)
    output = net(inputs)
    pred = output.max(1,keepdim=True)[1]
    print(pred)
    imgs_relu1 = np.squeeze(net.features['relu1'].cpu().numpy())
    print(imgs_relu1.shape)
    print(x.shape)
#     print(imgs_relu1[9])
    print(net.conv1.weight.size())
    img_show(np.squeeze(x))
    imgs_show( imgs_relu1,2,5)
    imgs_show(np.squeeze(net.conv1.weight),2,5)
    imgs_show(np.squeeze(net.conv2.weight),2,5)
# Out:
# tensor([[ 9]], device='cuda:0')
# (10, 12, 12)
# (1, 1, 28, 28)
# torch.Size([10, 1, 5, 5])
